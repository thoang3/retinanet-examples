# %%
from PIL import Image
from matplotlib.pyplot import imshow
import numpy as np

# %matplotlib inline

# %%
filepath = '/home/tung/playground/data/coco/images/val2017/000000312213.jpg'
im = Image.open(filepath).convert("RGB")

# %%
type(im)
# Out:
# PIL.Image.Image

# %%
imshow(im)

# %%
type(np.asarray(im))
# Out:
# numpy.ndarray

# %%
imshow(np.asarray(im))
